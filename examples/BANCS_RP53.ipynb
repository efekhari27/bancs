# %%
import numpy as np
import pandas as pd
import openturns as ot
from matplotlib import cm
from matplotlib import pyplot as plt
from bancs import *
import otbenchmark as otb

# %%
from matplotlib import rc, rcParams, style
#style.use('default')
rcParams['text.usetex'] = True
#rcParams['text.latex.unicode'] = True
rc('font', **{'family': 'Times'})
rc('text', usetex=True)
rc('font', size=16)# Set the default text font size
rc('axes', titlesize=20)# Set the axes title font size
rc('axes', labelsize=16)# Set the axes labels font size
rc('xtick', labelsize=14)# Set the font size for x tick labels
rc('ytick', labelsize=16)# Set the font size for y tick labels
rc('legend', fontsize=16)# Set the legend font size

# %%
import matplotlib as mpl
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
greys = mpl.colormaps['Greys_r']
faded_greys = ListedColormap(greys(np.linspace(0.4, 1., 128)))

# %% [markdown]
# ## RP 53 from the BBRC

# %%
problemRP53 = otb.ReliabilityProblem53()
failure_event = problemRP53.getEvent()
pf_ref = problemRP53.getProbability()

# %% [markdown]
# ## BACS : Bernstein Adaptive Conditional Sampling

# %%
N = int(1e4)
bancs = BANCS(failure_event, N=N, M=20, p0=0.1)
quantiles = bancs.run()
pf = bancs.compute_pf()
print("Quantiles =", quantiles)
print("Proba EBC = {:.2e}".format(pf))
print("Relative error = {:.2%}".format(np.abs(pf - pf_ref) / pf_ref))
fig = bancs.draw_2D_BANCS(colorbar=faded_greys)
plt.savefig("figures/bancs_rp57.pdf", bbox_inches='tight')
plt.savefig("figures/bancs_rp57.jpg", bbox_inches='tight', dpi=300);
# Out:
# Quantiles = [ 0.34288019 -0.42777953]
# Proba EBC = 3.21e-02
# Relative error = 2.44%

# %%
# Marginals goodness of fit
subset_idx = 1
xi = 1

sample = bancs.df[(bancs.df["Failed"]==1) & (bancs.df["Subset"]==subset_idx-1)]["X"+str(xi+1)].values.reshape(-1, 1) 
empirical = ot.UserDefined(sample)
fitted_marginal = bancs.conditional_distributions[subset_idx].getMarginal(xi)
graph = ot.HistogramFactory().build(sample, 30).drawCDF()
graph.add(empirical.drawCDF())
graph.add(fitted_marginal.drawCDF())
graph.setLegends(['Histogram', 'Empirical', 'KDE', 'KDE mixture'])
graph.setColors(['red','black', 'blue', 'green'])
graph
# Out:
# class=Graph name=cdf as a function of v0 implementation=class=GraphImplementation name=cdf as a function of v0 title= xTitle=v0 yTitle=CDF axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Histogram data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[1.25011,0],[1.28804,0],[1.32597,0],[1.3639,0],[1.40183,0],[1.43977,0],[1.4777,0],[1.51563,0],[1.55356,0],[1.59149,0],[1.62942,0],[1.66735,0],[1.70528,0],[1.74321,0.000605259],[1.78114,0.00144246],[1.81907,0.00227966],[1.857,0.00315581],[1.89493,0.00427208],[1.93286,0.00538835],[1.97079,0.00650462],[2.00872,0.00731044],[2.04665,0.00786858],[2.08458,0.00842671],[2.12251,0.00898484],[2.16044,0.00927149],[2.19837,0.00955055],[2.2363,0.00982962],[2.27423,0.0101087],[2.31216,0.0103878],[2.35009,0.0106668],[2.38802,0.0109459],[2.42595,0.0123497],[2.46388,0.0140241],[2.50181,0.0156985],[2.53974,0.0172486],[2.57767,0.0183649],[2.6156,0.0194812],[2.65353,0.0205974],[2.69146,0.0258174],[2.72939,0.0333522],[2.76732,0.040887],[2.80525,0.0490468],[2.84318,0.0677443],[2.88111,0.0864418],[2.91904,0.105139],[2.95697,0.12476],[2.9949,0.145411],[3.03283,0.166062],[3.07076,0.186713],[3.10869,0.205875],[3.14662,0.224851],[3.18455,0.243828],[3.22248,0.262378],[3.26041,0.279959],[3.29834,0.29754],[3.33627,0.315121],[3.3742,0.339759],[3.41213,0.367108],[3.45006,0.394456],[3.48799,0.420873],[3.52592,0.441524],[3.56385,0.462175],[3.60178,0.482826],[3.63971,0.505183],[3.67764,0.528904],[3.71557,0.552624],[3.7535,0.576345],[3.79143,0.598166],[3.82936,0.619933],[3.86729,0.641701],[3.90522,0.663468],[3.94315,0.685235],[3.98108,0.707002],[4.01901,0.728769],[4.05694,0.74604],[4.09487,0.762226],[4.1328,0.778412],[4.17073,0.793605],[4.20866,0.805326],[4.24659,0.817047],[4.28452,0.828768],[4.32245,0.840667],[4.36038,0.852667],[4.39831,0.864667],[4.43624,0.876496],[4.47417,0.885426],[4.51211,0.894356],[4.55004,0.903286],[4.58797,0.911558],[4.6259,0.919092],[4.66383,0.926627],[4.70176,0.934162],[4.73969,0.939713],[4.77762,0.945015],[4.81555,0.950317],[4.85348,0.955108],[4.89141,0.958736],[4.92934,0.962364],[4.96727,0.965992],[5.0052,0.96841],[5.04313,0.970364],[5.08106,0.972317],[5.11899,0.974387],[5.15692,0.977178],[5.19485,0.979968],[5.23278,0.982759],[5.27071,0.98493],[5.30864,0.986604],[5.34657,0.988279],[5.3845,0.989953],[5.42243,0.991356],[5.46036,0.992752],[5.49829,0.994147],[5.53622,0.995217],[5.57415,0.995775],[5.61208,0.996333],[5.65001,0.996891],[5.68794,0.997674],[5.72587,0.998511],[5.7638,0.999349],[5.80173,1],[5.83966,1],[5.87759,1],[5.91552,1],[5.95345,1],[5.99138,1],[6.02931,1],[6.06724,1],[6.10517,1]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2,class=Drawable name=v0 CDF implementation=class=Staircase name=v0 CDF pattern=s derived from class=DrawableImplementation name=v0 CDF legend=Empirical data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1002 dimension=2 data=[[1.26088,0],[1.71578,0.001],[1.76899,0.002],...,[5.72146,0.999],[5.79332,1],[6.09414,1]] color=black fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=2,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=KDE data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[1.23869,1.2198e-08],[1.27685,5.39474e-08],[1.31502,2.1461e-07],[1.35318,7.69045e-07],[1.39134,2.48661e-06],[1.4295,7.26915e-06],[1.46766,1.92579e-05],[1.50582,4.63668e-05],[1.54398,0.000101801],[1.58214,0.000204643],[1.62031,0.00037846],[1.65847,0.000647478],[1.69663,0.00103112],[1.73479,0.00153873],[1.77295,0.00216629],[1.81111,0.00289582],[1.84927,0.00369745],[1.88743,0.00453367],[1.9256,0.00536565],[1.96376,0.00616042],[2.00192,0.00689608],[2.04008,0.00756264],[2.07 ...

# %%
# Empirical Bernstein copula goodness of fit
subset_idx = 1
fitted_copula = bancs.conditional_distributions[subset_idx].getCopula()
sample = bancs.df[(bancs.df["Failed"]==1) & (bancs.df["Subset"]==subset_idx-1)][bancs.xlabels].values
#sample.setName('Subset sample $\mathbf{X}_N^{2} | g(\mathbf{X}_N^{2}) < \hat{q_N^{2}}$')
kendallPlot = ot.VisualTest.DrawKendallPlot(sample, fitted_copula)
kendallPlot
# Out:
# class=Graph name=Kendall Plot implementation=class=GraphImplementation name=Kendall Plot title=Kendall Plot xTitle=EmpiricalBernsteinCopula yTitle=Unnamed axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0,0],[1,1]] color=red fillStyle=solid lineStyle=dashed pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1000 dimension=2 data=[[0,0],[0,0],[0,0],...,[0.912032,0.874875],[0.925305,0.876877],[0.944104,0.880881]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1]
